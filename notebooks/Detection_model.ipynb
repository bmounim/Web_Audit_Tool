# %%
import os
import shutil

# Set the directory where you want to collect all images
target_directory = 'Output'

# Create the target directory if it doesn't exist
if not os.path.exists(target_directory):
    os.makedirs(target_directory)

# Set the root directory where the search for image files will begin
root_directory = 'ALL_folders'

# List of possible image extensions
image_extensions = ['.jpg', '.jpeg', '.png', '.gif', '.tiff', '.bmp', '.webp']

def collect_images(source_directory, target_directory, extensions):
    file_counter = 1  # Initialize counter for naming images sequentially
    for root, dirs, files in os.walk(source_directory):
        for file in files:
            if any(file.lower().endswith(ext) for ext in extensions):
                source_file_path = os.path.join(root, file)
                # Generate new file name based on the counter
                target_file_path = os.path.join(target_directory, f"{file_counter}{os.path.splitext(file)[1]}")
                
                shutil.copy2(source_file_path, target_file_path)
                print(f"Copied: {source_file_path} -> {target_file_path}")
                
                file_counter += 1  # Increment the counter for the next file

# Start the process
collect_images(root_directory, target_directory, image_extensions)

print("Image collection completed.")
# Out:
# Copied: ALL_folders\Chat support\1.png -> Output\1.png
# Copied: ALL_folders\Chat support\2.png -> Output\2.png
# Copied: ALL_folders\Chat support\3.png -> Output\3.png
# Copied: ALL_folders\Chat support\4.png -> Output\4.png
# Copied: ALL_folders\Chat support\5.png -> Output\5.png
# Copied: ALL_folders\Chat support\6.png -> Output\6.png
# Copied: ALL_folders\Chat support\7.png -> Output\7.png
# Copied: ALL_folders\Chat support\8.png -> Output\8.png
# Copied: ALL_folders\Delivery\aramex\10.webp -> Output\9.webp
# Copied: ALL_folders\Delivery\aramex\11.webp -> Output\10.webp
# Copied: ALL_folders\Delivery\aramex\12.jpeg -> Output\11.jpeg
# Copied: ALL_folders\Delivery\aramex\9.png -> Output\12.png
# Copied: ALL_folders\Delivery\azulcargoexpres\13.png -> Output\13.png
# Copied: ALL_folders\Delivery\azulcargoexpres\14.jpeg -> Output\14.jpeg
# Copied: ALL_folders\Delivery\azulcargoexpres\15.png -> Output\15.png
# Copied: ALL_folders\Delivery\bartolini\16.jpeg -> Output\16.jpeg
# Copied: ALL_folders\Delivery\bartolini\17.png -> Output\17.png
# Copied: ALL_folders\Delivery\bartolini\18.png -> Output\18.png
# Copied: ALL_folders\Delivery\chronopost\19.png -> Output\19.png
# Copied: ALL_folders\Delivery\chronopost\21.jpg -> Output\20.jpg
# Copied: ALL_folders\Delivery\correios\21.png -> Output\21.png
# Copied: ALL_folders\Delivery\correios\22.png -> Output\22.png
# Copied: ALL_folders\Delivery\correios\23.png -> Output\23.png
# Copied: ALL_folders\Delivery\correos\24.png -> Output\24.png
# Copied: ALL_folders\Delivery\correos\25.webp -> Output\25.webp
# Copied: ALL_folders\Delivery\correos\26.png -> Output\26.png
# Copied: ALL_folders\Delivery\deutschepost\27.jpg -> Output\27.jpg
# Copied: ALL_folders\Delivery\deutschepost\28.jpeg -> Output\28.jpeg
# Copied: ALL_folders\Delivery\deutschepost\29.png -> Output\29.png
# Copied: ALL_folders\Delivery\dhl\30.png -> Output\30.png
# Copied: ALL_folders\Delivery\dhl\31.png -> Output\31.png
# Copied: ALL_folders\Delivery\dhl\32.png -> Output\32.png
# Copied: ALL_folders\Delivery\dhl\33.jpg -> Output\33.jpg
# Copied: ALL_folders\Delivery\dpd\34.png -> Output\34.png
# Copied: ALL_folders\Delivery\dpd\35.png -> Output\35.png
# Copied: ALL_folders\Delivery\dpd\36.png -> Output\36.png
# Copied: ALL_folders\Delivery\emiratespost\37.jpeg -> Output\37.jpeg
# Copied: ALL_folders\Delivery\emiratespost\38.png -> Output\38.png
# Copied: ALL_folders\Delivery\emiratespost\39.jpg -> Output\39.jpg
# Copied: ALL_folders\Delivery\fedex\40.png -> Output\40.png
# Copied: ALL_folders\Delivery\fedex\41.jpg -> Output\41.jpg
# Copied: ALL_folders\Delivery\fedex\42.webp -> Output\42.webp
# Copied: ALL_folders\Delivery\gls\download.png -> Output\43.png
# Copied: ALL_folders\Delivery\gls\rivne-ukraine-august-10-2023-260nw-2345976145.webp -> Output\44.webp
# Copied: ALL_folders\Delivery\hermes\download (1).png -> Output\45.png
# Copied: ALL_folders\Delivery\hermes\download.png -> Output\46.png
# Copied: ALL_folders\Delivery\hermes\Hermes-Logo-1024x683.webp -> Output\47.webp
# Copied: ALL_folders\Delivery\jadlog\download.jpeg -> Output\48.jpeg
# Copied: ALL_folders\Delivery\jadlog\images.jpeg -> Output\49.jpeg
# Copied: ALL_folders\Delivery\jadlog\jadlog-45a7a1fc29712fb160901f52e82357535db29efc98bf81d7c0bc3f03a5bcfd97.png -> Output\50.png
# Copied: ALL_folders\Delivery\jadlog\logo_jadlog.png -> Output\51.png
# Copied: ALL_folders\Delivery\loggi\download.png -> Output\52.png
# Copied: ALL_folders\Delivery\loggi\loggi_11700_logo_1641374907_1h3lt.png -> Output\53.png
# Copied: ALL_folders\Delivery\loggi\main-qimg-f63035d669763deb2db66770eafe16e6.jpeg -> Output\54.jpeg
# Copied: ALL_folders\Delivery\loggi\sao-paulo-brazil-march-25-260nw-1683958489.webp -> Output\55.webp
# Copied: ALL_folders\Delivery\mondialrelay\download (1).png -> Output\56.png
# Copied: ALL_folders\Delivery\mondialrelay\download.png -> Output\57.png
# Copied: ALL_folders\Delivery\posteitaliane\download (1).png -> Output\58.png
# Copied: ALL_folders\Delivery\posteitaliane\download.jpeg -> Output\59.jpeg
# Copied: ALL_folders\Delivery\posteitaliane\download.png -> Output\60.png
# Copied: ALL_folders\Delivery\seur\download.png -> Output\61.png
# Copied: ALL_folders\Delivery\seur\logo.png -> Output\62.png
# Copied: ALL_folders\Delivery\seur\SEUR logo.png -> Output\63.png
# Copied: ALL_folders\Delivery\totalexpres\banner-6.jpg -> Output\64.jpg
# Copied: ALL_folders\Delivery\totalexpres\download.jpeg -> Output\65.jpeg
# Copied: ALL_folders\Delivery\totalexpres\download.png -> Output\66.png
# Copied: ALL_folders\Delivery\ups\download.png -> Output\67.png
# Copied: ALL_folders\Delivery\ups\UPS-logo.png -> Output\68.png
# Copied: ALL_folders\Delivery\usps\download (1).png -> Output\69.png
# Copied: ALL_folders\Delivery\usps\download.png -> Output\70.png
# Copied: ALL_folders\Delivery\usps\united-states-postal-service-logo-us-usps-editorial-201271087.webp -> Output\71.webp
# Copied: ALL_folders\Payments\americanexpress\72.jpg -> Output\72.jpg
# Copied: ALL_folders\Payments\americanexpress\73.png -> Output\73.png
# Copied: ALL_folders\Payments\americanexpress\74.jpeg -> Output\74.jpeg
# Copied: ALL_folders\Payments\americanexpress\75.png -> Output\75.png
# Copied: ALL_folders\Payments\americanexpress\76.png -> Output\76.png
# Copied: ALL_folders\Payments\americanexpress\77.jpeg -> Output\77.jpeg
# Copied: ALL_folders\Payments\americanexpress\78.png -> Output\78.png
# Copied: ALL_folders\Payments\americanexpress\79.webp -> Output\79.webp
# Copied: ALL_folders\Payments\bancomat\Bancomat_logo.png -> Output\80.png
# Copied: ALL_folders\Payments\bancomat\images.jpeg -> Output\81.jpeg
# Copied: ALL_folders\Payments\bancomat\Logo_Bancomat_(2018).svg.png -> Output\82.png
# Copied: ALL_folders\Payments\bancomat\url_59a4200c0fb86074d5130ffe.jpg -> Output\83.jpg
# Copied: ALL_folders\Payments\bancomatpay\2846.webp -> Output\84.webp
# Copied: ALL_folders\Payments\bancomatpay\download (1).jpeg -> Output\85.jpeg
# Copied: ALL_folders\Payments\bancomatpay\download.jpeg -> Output\86.jpeg
# Copied: ALL_folders\Payments\bancomatpay\hq720.jpg -> Output\87.jpg
# Copied: ALL_folders\Payments\bizum\download (1).png -> Output\88.png
# Copied: ALL_folders\Payments\bizum\download (2).png -> Output\89.png
# Copied: ALL_folders\Payments\bizum\download (3).png -> Output\90.png
# Copied: ALL_folders\Payments\bizum\download.png -> Output\91.png
# Copied: ALL_folders\Payments\bizum\image-0db8580d405248379b2daa04fac380bc.jpg -> Output\92.jpg
# Copied: ALL_folders\Payments\bizum\maxresdefault.jpg -> Output\93.jpg
# Copied: ALL_folders\Payments\boleto\boleto-logo-4.png -> Output\94.png
# Copied: ALL_folders\Payments\boleto\boleto-logo-A84D741D5E-seeklogo.com.png -> Output\95.png
# Copied: ALL_folders\Payments\boleto\boleto.png -> Output\96.png
# Copied: ALL_folders\Payments\boleto\download.png -> Output\97.png
# Copied: ALL_folders\Payments\boleto\images.jpeg -> Output\98.jpeg
# Copied: ALL_folders\Payments\boleto\images.png -> Output\99.png
# Copied: ALL_folders\Payments\cartebancaire\25032020_stickers_autocollant_paiement_cb_carte_bancaire_sans_contact_master-card-visa.webp -> Output\100.webp
# Copied: ALL_folders\Payments\cartebancaire\cb-carte-bleue-logo-FD1C2ABA3B-seeklogo.com.png -> Output\101.png
# Copied: ALL_folders\Payments\cartebancaire\download.jpeg -> Output\102.jpeg
# Copied: ALL_folders\Payments\cartebancaire\download.png -> Output\103.png
# Copied: ALL_folders\Payments\cartebancaire\vitrophanie-CB-1.jpg -> Output\104.jpg
# Copied: ALL_folders\Payments\cashapp\Cash-App-Emblem.png -> Output\105.png
# Copied: ALL_folders\Payments\cashapp\download (1).png -> Output\106.png
# Copied: ALL_folders\Payments\cashapp\download.png -> Output\107.png
# Copied: ALL_folders\Payments\cashapp\Support-Contact-Cash-App-US-1.png -> Output\108.png
# Copied: ALL_folders\Payments\cashondelivery_uae\cash-on-delivery-logo-cod-260nw-2192932617.webp -> Output\109.webp
# Copied: ALL_folders\Payments\cashondelivery_uae\download (1).png -> Output\110.png
# Copied: ALL_folders\Payments\cashondelivery_uae\download.jpeg -> Output\111.jpeg
# Copied: ALL_folders\Payments\cashondelivery_uae\download.png -> Output\112.png
# Copied: ALL_folders\Payments\cashondelivery_uae\pngtree-cash-on-delivery-pin-point-png-image_3342464.jpg -> Output\113.jpg
# Copied: ALL_folders\Payments\cashondelivery_uae\vector-stock-cod-cash-on-260nw-2205856805.webp -> Output\114.webp
# Copied: ALL_folders\Payments\elo\1024px-Elo_card_association_logo_-_black_text.svg.png -> Output\115.png
# Copied: ALL_folders\Payments\elo\download (1).png -> Output\116.png
# Copied: ALL_folders\Payments\elo\PME-Elo.png -> Output\117.png
# Copied: ALL_folders\Payments\elo\visa-logo-paypal-logo-elo-logo-master-card-logo-hipercard-logo-finance-logo-set-of-popular-logos-printed-on-paper-2JPRJE4.jpg -> Output\118.jpg
# Copied: ALL_folders\Payments\general\2560px-Amazon_Pay_logo.svg.png -> Output\119.png
# Copied: ALL_folders\Payments\general\360_F_455102361_RsJAeKOVlrrbvLLRtrFQ3K6VAuDg0b4b.jpg -> Output\120.jpg
# Copied: ALL_folders\Payments\general\360_F_473846184_0k637f6855ZJqaulKqAmgJTEVGVibR1P.jpg -> Output\121.jpg
# Copied: ALL_folders\Payments\general\360_F_486770467_9nd0TjY0owEdwkoUCvi85VfIJQTvQFKi.jpg -> Output\122.jpg
# Copied: ALL_folders\Payments\general\3fdd00181850867.652392bf820f8.jpg -> Output\123.jpg
# Copied: ALL_folders\Payments\general\50074623521_962a89ce0d_b.jpg -> Output\124.jpg
# Copied: ALL_folders\Payments\general\581fe48e03f0dbb710049576b3b7986a.jpg -> Output\125.jpg
# Copied: ALL_folders\Payments\general\aa3701175878191.64badf9ce7013.png -> Output\126.png
# Copied: ALL_folders\Payments\general\allLogos.png -> Output\127.png
# Copied: ALL_folders\Payments\general\Amex.webp -> Output\128.webp
# Copied: ALL_folders\Payments\general\digital-fast-payment-wallet-logo-600nw-1187176081.webp -> Output\129.webp
# Copied: ALL_folders\Payments\general\download.png -> Output\130.png
# Copied: ALL_folders\Payments\general\ed31f29731a0ba7e2110fae9699e6131.jpg -> Output\131.jpg
# Copied: ALL_folders\Payments\general\fast-money-logo-design-template-260nw-2133883235.webp -> Output\132.webp
# Copied: ALL_folders\Payments\general\fast-pay-logo-design-finance-260nw-1669932124.webp -> Output\133.webp
# Copied: ALL_folders\Payments\general\fast-wallet-mobile-internet-payment-260nw-2086561786.webp -> Output\134.webp
# Copied: ALL_folders\Payments\general\gratis-png-logo-maestro-maestro-tarjeta-de-debito-tarjeta-de-credito-pago-vpay-logo-mastercard-thumbnail.png -> Output\135.png
# Copied: ALL_folders\Payments\general\IDEAL_Logo.png -> Output\136.png
# Copied: ALL_folders\Payments\general\images (1).jpeg -> Output\137.jpeg
# Copied: ALL_folders\Payments\general\images (1).png -> Output\138.png
# Copied: ALL_folders\Payments\general\images (10).png -> Output\139.png
# Copied: ALL_folders\Payments\general\images (11).png -> Output\140.png
# Copied: ALL_folders\Payments\general\images (12).png -> Output\141.png
# Copied: ALL_folders\Payments\general\images (13).png -> Output\142.png
# Copied: ALL_folders\Payments\general\images (14).png -> Output\143.png
# Copied: ALL_folders\Payments\general\images (15).png -> Output\144.png
# Copied: ALL_folders\Payments\general\images (16).png -> Output\145.png
# Copied: ALL_folders\Payments\general\images (17).png -> Output\146.png
# Copied: ALL_folders\Payments\general\images (18).png -> Output\147.png
# Copied: ALL_folders\Payments\general\images (19).png -> Output\148.png
# Copied: ALL_folders\Payments\general\images (2).jpeg -> Output\149.jpeg
# Copied: ALL_folders\Payments\general\images (2).png -> Output\150.png
# Copied: ALL_folders\Payments\general\images (20).png -> Output\151.png
# Copied: ALL_folders\Payments\general\images (3).jpeg -> Output\152.jpeg
# Copied: ALL_folders\Payments\general\images (3).png -> Output\153.png
# Copied: ALL_folders\Payments\general\images (4).jpeg -> Output\154.jpeg
# Copied: ALL_folders\Payments\general\images (4).png -> Output\155.png
# Copied: ALL_folders\Payments\general\images (5).jpeg -> Output\156.jpeg
# Copied: ALL_folders\Payments\general\images (5).png -> Output\157.png
# Copied: ALL_folders\Payments\general\images (6).jpeg -> Output\158.jpeg
# Copied: ALL_folders\Payments\general\images (6).png -> Output\159.png
# Copied: ALL_folders\Payments\general\images (7).png -> Output\160.png
# Copied: ALL_folders\Payments\general\images (8).png -> Output\161.png
# Copied: ALL_folders\Payments\general\images (9).png -> Output\162.png
# Copied: ALL_folders\Payments\general\images.jpeg -> Output\163.jpeg
# Copied: ALL_folders\Payments\general\images.png -> Output\164.png
# Copied: ALL_folders\Payments\general\kisspng-visa-logo-mastercard-credit-card-payment-5b15b13e347986.454908321528148286215.jpg -> Output\165.jpg
# Copied: ALL_folders\Payments\general\logo-amex.webp -> Output\166.webp
# Copied: ALL_folders\Payments\general\money-payment-logo-vector-24006068.jpg -> Output\167.jpg
# Copied: ALL_folders\Payments\general\pay-logo-design-vector-template-260nw-2143879869 (1).webp -> Output\168.webp
# Copied: ALL_folders\Payments\general\pay-logo-design-vector-template-260nw-2143879869.webp -> Output\169.webp
# Copied: ALL_folders\Payments\general\pay-with-lightning-network-bitcoin-logo-v2-sticker.jpg -> Output\170.jpg
# Copied: ALL_folders\Payments\general\payment-method-credit-card-logos-icons-20.jpg -> Output\171.jpg
# Copied: ALL_folders\Payments\general\payment-methods-logos.png -> Output\172.png
# Copied: ALL_folders\Payments\general\payment-smartphone-icon-online-mobile-600nw-1191138346.webp -> Output\173.webp
# Copied: ALL_folders\Payments\general\payments-icon-21.png -> Output\174.png
# Copied: ALL_folders\Payments\general\paypal-payments.webp -> Output\175.webp
# Copied: ALL_folders\Payments\general\payvand-payment-system-logo-5F82538251-seeklogo.com.png -> Output\176.png
# Copied: ALL_folders\Payments\general\png-clipart-paypal-logo-brand-font-payment-paypal-text-logo.png -> Output\177.png
# Copied: ALL_folders\Payments\general\qr-payments-wallet-money-tip-260nw-2213900913.webp -> Output\178.webp
# Copied: ALL_folders\Payments\general\shop-pay-logo-color-e824c8c627de20423f3abba730d2d5df83c5b848847f029f91ec1bd011f6b0e3.webp -> Output\179.webp
# Copied: ALL_folders\Payments\general\shop-pay-monotone-logo-examples-17a6482e2a24b7f5d174b29342f3656d2417f07fa56f797a99f54022b0aedc22.webp -> Output\180.webp
# Copied: ALL_folders\Payments\general\Tiny-Payment-Method-Icons.webp -> Output\181.webp
# Copied: ALL_folders\Payments\general\Union_Pay.webp -> Output\182.webp
# Copied: ALL_folders\Payments\general\wechat_obszar_roboczy_1.jpg -> Output\183.jpg
# Copied: ALL_folders\Payments\general\支付宝vs微信支付_810-421.jpg -> Output\184.jpg
# Copied: ALL_folders\Payments\giropay\download.jpeg -> Output\185.jpeg
# Copied: ALL_folders\Payments\giropay\download.png -> Output\186.png
# Copied: ALL_folders\Payments\hipercard\download (1).png -> Output\187.png
# Copied: ALL_folders\Payments\hipercard\download.png -> Output\188.png
# Copied: ALL_folders\Payments\hipercard\images.png -> Output\189.png
# Copied: ALL_folders\Payments\klarna\download (2).png -> Output\190.png
# Copied: ALL_folders\Payments\mastercard\download.png -> Output\191.png
# Copied: ALL_folders\Payments\mastercard\images (1).jpeg -> Output\192.jpeg
# Copied: ALL_folders\Payments\paypal\images.jpeg -> Output\193.jpeg
# Copied: ALL_folders\Payments\paypal\images.png -> Output\194.png
# Copied: ALL_folders\Payments\paypal\PayPal-Logo.png -> Output\195.png
# Copied: ALL_folders\Payments\pix\10009139.jpg -> Output\196.jpg
# Copied: ALL_folders\Payments\pix\16512_9BAA43711F9F02DB.webp -> Output\197.webp
# Copied: ALL_folders\Payments\pix\63e6a6e66cd89pix.webp -> Output\198.webp
# Copied: ALL_folders\Payments\pix\6d7db3c24b464134c3de9903ad5cd2ca.jpeg -> Output\199.jpeg
# Copied: ALL_folders\Payments\pix\afa837e483ce02a72221688cf1f4adca.jpeg -> Output\200.jpeg
# Copied: ALL_folders\Payments\pix\arte-digital-pagamento-pix-com-qr-code.webp -> Output\201.webp
# Copied: ALL_folders\Payments\pix\br-11134201-23020-0rw2oaf4jjnv97.jpeg -> Output\202.jpeg
# Copied: ALL_folders\Payments\pix\download (1).png -> Output\203.png
# Copied: ALL_folders\Payments\pix\download (2).png -> Output\204.png
# Copied: ALL_folders\Payments\pix\download (3).png -> Output\205.png
# Copied: ALL_folders\Payments\pix\download.jpeg -> Output\206.jpeg
# Copied: ALL_folders\Payments\pix\download.png -> Output\207.png
# Copied: ALL_folders\Payments\pix\D_NQ_NP_677221-MLB50206057865_062022-O.webp -> Output\208.webp
# Copied: ALL_folders\Payments\pix\D_NQ_NP_682909-MLB51569674731_092022-O.webp -> Output\209.webp
# Copied: ALL_folders\Payments\pix\D_NQ_NP_721849-MLB52539931784_112022-O.webp -> Output\210.webp
# Copied: ALL_folders\Payments\pix\ef1bd33fd1687c7f9c5df613bc315132.jpeg -> Output\211.jpeg
# Copied: ALL_folders\Payments\pix\este-estabelecimento-aceita-pagamentos-com-pix-banco-central-n54ix7p8aa.webp -> Output\212.webp
# Copied: ALL_folders\Payments\pix\f2qb6fgnespdbqhgp1v7s5pax.webp -> Output\213.webp
# Copied: ALL_folders\Payments\pix\fid-tr-fc00461-1703be65515afc23d416285296700878-480-0.png -> Output\214.png
# Copied: ALL_folders\Payments\pix\fid-tr-fc00471-8b6bb023f674bcdf6716285298461890-480-0.png -> Output\215.png
# Copied: ALL_folders\Payments\pix\images (1).jpeg -> Output\216.jpeg
# Copied: ALL_folders\Payments\pix\images (1).png -> Output\217.png
# Copied: ALL_folders\Payments\pix\images (10).jpeg -> Output\218.jpeg
# Copied: ALL_folders\Payments\pix\images (10).png -> Output\219.png
# Copied: ALL_folders\Payments\pix\images (11).jpeg -> Output\220.jpeg
# Copied: ALL_folders\Payments\pix\images (11).png -> Output\221.png
# Copied: ALL_folders\Payments\pix\images (12).jpeg -> Output\222.jpeg
# Copied: ALL_folders\Payments\pix\images (13).jpeg -> Output\223.jpeg
# Copied: ALL_folders\Payments\pix\images (14).jpeg -> Output\224.jpeg
# Copied: ALL_folders\Payments\pix\images (2).jpeg -> Output\225.jpeg
# Copied: ALL_folders\Payments\pix\images (2).png -> Output\226.png
# Copied: ALL_folders\Payments\pix\images (3).jpeg -> Output\227.jpeg
# Copied: ALL_folders\Payments\pix\images (3).png -> Output\228.png
# Copied: ALL_folders\Payments\pix\images (4).jpeg -> Output\229.jpeg
# Copied: ALL_folders\Payments\pix\images (4).png -> Output\230.png
# Copied: ALL_folders\Payments\pix\images (5).jpeg -> Output\231.jpeg
# Copied: ALL_folders\Payments\pix\images (5).png -> Output\232.png
# Copied: ALL_folders\Payments\pix\images (6).jpeg -> Output\233.jpeg
# Copied: ALL_folders\Payments\pix\images (6).png -> Output\234.png
# Copied: ALL_folders\Payments\pix\images (7).jpeg -> Output\235.jpeg
# Copied: ALL_folders\Payments\pix\images (7).png -> Output\236.png
# Copied: ALL_folders\Payments\pix\images (8).jpeg -> Output\237.jpeg
# Copied: ALL_folders\Payments\pix\images (8).png -> Output\238.png
# Copied: ALL_folders\Payments\pix\images (9).jpeg -> Output\239.jpeg
# Copied: ALL_folders\Payments\pix\images (9).png -> Output\240.png
# Copied: ALL_folders\Payments\pix\images.jpeg -> Output\241.jpeg
# Copied: ALL_folders\Payments\pix\images.png -> Output\242.png
# Copied: ALL_folders\Payments\pix\Logo—pix_powered_by_Banco_Central_(Brazil,_2020).svg.png -> Output\243.png
# Copied: ALL_folders\Payments\pix\mGuL0ET.png -> Output\244.png
# Copied: ALL_folders\Payments\pix\o-que-e-o-pix-1536x1002-1.webp -> Output\245.webp
# Copied: ALL_folders\Payments\pix\pix (1).jpg -> Output\246.jpg
# Copied: ALL_folders\Payments\pix\Pix-1280x720-1.webp -> Output\247.webp
# Copied: ALL_folders\Payments\pix\pix-banco-central-brasil-logo-700C1B323C-seeklogo.com.png -> Output\248.png
# Copied: ALL_folders\Payments\pix\pix.jpg -> Output\249.jpg
# Copied: ALL_folders\Payments\pix\pix_capa-3_tb-1060x596.jpeg -> Output\250.jpeg
# Copied: ALL_folders\Payments\pix\Placa_Pix_Em_Branco_250X50Mm_1_6ef9258618855e15a5c8131d5c349819.jpg -> Output\251.jpg
# Copied: ALL_folders\Payments\postepay\64fe0535aeece9494133f106_6489b972bece4b8013936795_Postepay%20Main%20Image.webp -> Output\252.webp
# Copied: ALL_folders\Payments\postepay\Carte-accettate.webp -> Output\253.webp
# Copied: ALL_folders\Payments\postepay\download.jpeg -> Output\254.jpeg
# Copied: ALL_folders\Payments\postepay\download.png -> Output\255.png
# Copied: ALL_folders\Payments\postepay\images.jpeg -> Output\256.jpeg
# Copied: ALL_folders\Payments\postepay\images.png -> Output\257.png
# Copied: ALL_folders\Payments\postepay\PostePay.webp -> Output\258.webp
# Copied: ALL_folders\Payments\sofort\29b6e9bda418e10f30afc7656e8a6e0bd482d91d.png -> Output\259.png
# Copied: ALL_folders\Payments\sofort\logo-sofort-png.png -> Output\260.png
# Copied: ALL_folders\Payments\sofort\Sofort.webp -> Output\261.webp
# Copied: ALL_folders\Payments\venmo\1658499429798.png -> Output\262.png
# Copied: ALL_folders\Payments\venmo\App_Icon.png -> Output\263.png
# Copied: ALL_folders\Payments\venmo\images.jpeg -> Output\264.jpeg
# Copied: ALL_folders\Payments\venmo\images.png -> Output\265.png
# Copied: ALL_folders\Payments\venmo\Venmo_Logo.svg.png -> Output\266.png
# Copied: ALL_folders\Payments\visa\download.png -> Output\267.png
# Copied: ALL_folders\Payments\visa\png-clipart-visa-logo-credit-card-e-commerce-visa-payment-mastercard-visa-company-text.png -> Output\268.png
# Copied: ALL_folders\Payments\visa\Visa_Debit_SVG_logo.svg.png -> Output\269.png
# Copied: ALL_folders\Trustmarks\avis_france\avis_vrifis_logo.jpeg -> Output\270.jpeg
# Copied: ALL_folders\Trustmarks\avis_france\chzckvk8zjcpxqgnsj31.webp -> Output\271.webp
# Copied: ALL_folders\Trustmarks\avis_france\dreaminjob-logo-avisverfies.jpg -> Output\272.jpg
# Copied: ALL_folders\Trustmarks\avis_france\idhFuBuXsg.png -> Output\273.png
# Copied: ALL_folders\Trustmarks\avis_france\logo-avis-verifies (1).png -> Output\274.png
# Copied: ALL_folders\Trustmarks\avis_france\logo-avis-verifies.png -> Output\275.png
# Copied: ALL_folders\Trustmarks\betterbusinessbureau\bbb.webp -> Output\276.webp
# Copied: ALL_folders\Trustmarks\betterbusinessbureau\download (1).png -> Output\277.png
# Copied: ALL_folders\Trustmarks\betterbusinessbureau\download.png -> Output\278.png
# Copied: ALL_folders\Trustmarks\betterbusinessbureau\images.png -> Output\279.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\64966de850390e685028b4dd_sample-google-review-badge.png -> Output\280.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\download (2).png -> Output\281.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\download.jpeg -> Output\282.jpeg
# Copied: ALL_folders\Trustmarks\googlereviews_uae\download.png -> Output\283.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\google-review-logo.png -> Output\284.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\Google-Reviews-Logo-v2.webp -> Output\285.webp
# Copied: ALL_folders\Trustmarks\googlereviews_uae\images.png -> Output\286.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\medium-widget-3 (1).png -> Output\287.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\medium-widget-3.png -> Output\288.png
# Copied: ALL_folders\Trustmarks\googlereviews_uae\recensioni-google.webp -> Output\289.webp
# Copied: ALL_folders\Trustmarks\opinionsverificadas\download.jpeg -> Output\290.jpeg
# Copied: ALL_folders\Trustmarks\opinionsverificadas\logoAvisVerifies_400.jpg -> Output\291.jpg
# Copied: ALL_folders\Trustmarks\opinionsverificadas\logo_footer.png -> Output\292.png
# Copied: ALL_folders\Trustmarks\opinionsverificadas\opiniones-clientes-dataweb.png -> Output\293.png
# Copied: ALL_folders\Trustmarks\reclameaqui\f400x0-28999_29017_0.jpg -> Output\294.jpg
# Copied: ALL_folders\Trustmarks\reclameaqui\image2.png -> Output\295.png
# Copied: ALL_folders\Trustmarks\reclameaqui\images (1).png -> Output\296.png
# Copied: ALL_folders\Trustmarks\reclameaqui\images.jpeg -> Output\297.jpeg
# Copied: ALL_folders\Trustmarks\reclameaqui\images.png -> Output\298.png
# Copied: ALL_folders\Trustmarks\reclameaqui\selo-Reclame-AQUI_.png -> Output\299.png
# Copied: ALL_folders\Trustmarks\reviews.io\629652c42be59dc55430cabb (1).png -> Output\300.png
# Copied: ALL_folders\Trustmarks\reviews.io\629652c42be59dc55430cabb.png -> Output\301.png
# Copied: ALL_folders\Trustmarks\reviews.io\download (1).png -> Output\302.png
# Copied: ALL_folders\Trustmarks\reviews.io\download.png -> Output\303.png
# Copied: ALL_folders\Trustmarks\trustedshops\@2xtrustmark-header-1.png -> Output\304.png
# Copied: ALL_folders\Trustmarks\trustedshops\Bildschirmfoto-2020-12-21-um-15.09.40.png -> Output\305.png
# Copied: ALL_folders\Trustmarks\trustedshops\download.jpeg -> Output\306.jpeg
# Copied: ALL_folders\Trustmarks\trustedshops\download.png -> Output\307.png
# Copied: ALL_folders\Trustmarks\trustedshops\Examples-of-Trust-Badges.webp -> Output\308.webp
# Copied: ALL_folders\Trustmarks\trustedshops\trustbadge-mobile-1.png -> Output\309.png
# Copied: ALL_folders\Trustmarks\trustedshops\trustbadge-mobile-2.png -> Output\310.png
# Copied: ALL_folders\Trustmarks\trustpilot\0x0.png -> Output\311.png
# Copied: ALL_folders\Trustmarks\trustpilot\images.png -> Output\312.png
# Copied: ALL_folders\Trustmarks\trustpilot\Image_4.png -> Output\313.png
# Copied: ALL_folders\Trustmarks\trustpilot\TrustPilot-Excellent--300x300.png -> Output\314.png
# Copied: ALL_folders\Trustmarks\yotpo\download (1).png -> Output\315.png
# Copied: ALL_folders\Trustmarks\yotpo\download.png -> Output\316.png
# Copied: ALL_folders\Trustmarks\yotpo\frame_88_1_.webp -> Output\317.webp
# Copied: ALL_folders\Trustmarks\yotpo\yotpo-product-reviews.webp -> Output\318.webp
# Image collection completed.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\admin\appdata\local\programs\python\python312\lib\site-packages (from opencv-python) (1.26.2)
# Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl (38.6 MB)
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/38.6 MB 4.2 MB/s eta 0:00:10
#     --------------------------------------- 0.7/38.6 MB 6.5 MB/s eta 0:00:06
#    - -------------------------------------- 1.3/38.6 MB 9.3 MB/s eta 0:00:05
#    - -------------------------------------- 1.9/38.6 MB 10.1 MB/s eta 0:00:04
#    -- ------------------------------------- 2.5/38.6 MB 10.8 MB/s eta 0:00:04
#    --- ------------------------------------ 3.2/38.6 MB 11.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.0/38.6 MB 12.0 MB/s eta 0:00:03
#    ---- ----------------------------------- 4.6/38.6 MB 12.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.0/38.6 MB 11.9 MB/s eta 0:00:03
#    ------ --------------------------------- 5.8/38.6 MB 12.4 MB/s eta 0:00:03
#    ------ --------------------------------- 6.6/38.6 MB 12.7 MB/s eta 0:00:03
#    ------- -------------------------------- 7.2/38.6 MB 12.8 MB/s eta 0:00:03
#    -------- ------------------------------- 8.0/38.6 MB 13.0 MB/s eta 0:00:03
#    --------- ------------------------------ 8.8/38.6 MB 13.4 MB/s eta 0:00:03
#    --------- ------------------------------ 9.3/38.6 MB 13.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.3/38.6 MB 13.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.0/38.6 MB 14.9 MB/s eta 0:00:02
#    ------------ --------------------------- 11.7/38.6 MB 14.9 MB/s eta 0:00:02
#    ------------ --------------------------- 12.5/38.6 MB 15.2 MB/s eta 0:00:02
#    ------------- -------------------------- 13.2/38.6 MB 15.2 MB/s eta 0:00:02
#    -------------- ------------------------- 14.1/38.6 MB 15.6 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/38.6 MB 15.6 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.5/38.6 MB 16.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 16.2/38.6 MB 16.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.9/38.6 MB 16.0 MB/s eta 0:00:02
#    ------------------ --------------------- 17.6/38.6 MB 16.0 MB/s eta 0:00:02
#    ------------------ --------------------- 18.3/38.6 MB 15.6 MB/s eta 0:00:02
#    ------------------- -------------------- 19.0/38.6 MB 15.6 MB/s eta 0:00:02
#    -------------------- ------------------- 19.8/38.6 MB 16.0 MB/s eta 0:00:02
#    --------------------- ------------------ 20.5/38.6 MB 15.6 MB/s eta 0:00:02
#    --------------------- ------------------ 21.2/38.6 MB 15.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.9/38.6 MB 15.6 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.7/38.6 MB 15.6 MB/s eta 0:00:02
#    ------------------------ --------------- 23.2/38.6 MB 15.2 MB/s eta 0:00:02
#    ------------------------ --------------- 24.1/38.6 MB 15.2 MB/s eta 0:00:01
#    ------------------------- -------------- 24.9/38.6 MB 16.0 MB/s eta 0:00:01
#    -------------------------- ------------- 25.5/38.6 MB 15.6 MB/s eta 0:00:01
#    --------------------------- ------------ 26.2/38.6 MB 15.6 MB/s eta 0:00:01
#    --------------------------- ------------ 26.9/38.6 MB 15.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.6/38.6 MB 15.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.3/38.6 MB 15.6 MB/s eta 0:00:01
#    ------------------------------ --------- 29.1/38.6 MB 15.6 MB/s eta 0:00:01
#    ------------------------------ --------- 29.9/38.6 MB 15.6 MB/s eta 0:00:01
#    ------------------------------- -------- 30.7/38.6 MB 16.0 MB/s eta 0:00:01
#    -------------------------------- ------- 31.6/38.6 MB 16.0 MB/s eta 0:00:01
#    --------------------------------- ------ 32.4/38.6 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.1/38.6 MB 16.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.9/38.6 MB 16.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.6/38.6 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------ --- 35.4/38.6 MB 16.4 MB/s eta 0:00:01
#    ------------------------------------- -- 36.1/38.6 MB 16.8 MB/s eta 0:00:01
#    -------------------------------------- - 36.9/38.6 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------  37.8/38.6 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.6 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------  38.6/38.6 MB 17.2 MB/s eta 0:00:01
#    ---------------------------------------- 38.6/38.6 MB 14.6 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.9.0.80
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from glob import glob

def create_gray_background(height, width, gray_level=220):
    """Creates a uniform gray background image."""
    return np.full((height, width, 3), gray_level, dtype=np.uint8)

def apply_transformations_and_overlay_on_gray(logo, background_size=(1024, 1024), scale_range=(0.05, 0.2)):
    # Generate a gray background
    background = create_gray_background(*background_size)
    
    # Scale the logo to a random size within the specified range
    scale = np.random.uniform(*scale_range)
    logo_height, logo_width = logo.shape[:2]
    new_width = int(logo_width * scale)
    new_height = int(logo_height * scale)
    resized_logo = cv2.resize(logo, (new_width, new_height), interpolation=cv2.INTER_AREA)
    
    # Ensure the logo has an alpha channel; if not, create a dummy one
    if logo.shape[2] == 3:  # No alpha channel
        logo = np.concatenate([logo, np.full((logo.shape[0], logo.shape[1], 1), 255, dtype=np.uint8)], axis=-1)
    
    # Choose a random position for the logo
    max_x = background_size[1] - new_width
    max_y = background_size[0] - new_height
    x = np.random.randint(0, max_x)
    y = np.random.randint(0, max_y)
    
    # Overlay the logo onto the gray background
    for c in range(0, 3):
        alpha_logo = resized_logo[:, :, 3] / 255.0
        alpha_bg = 1.0 - alpha_logo
        background[y:y+new_height, x:x+new_width, c] = (alpha_logo * resized_logo[:, :, c] +
                                                        alpha_bg * background[y:y+new_height, x:x+new_width, c])
    return background

def generate_synthetic_images_on_gray(logos_path, output_path, num_images_per_logo=10, background_size=(1024, 1024)):
    # Support multiple image formats
    image_extensions = ['*.png', '*.webp', '*.jpeg', '*.jpg']
    logos = []
    for extension in image_extensions:
        logos.extend(glob(os.path.join(logos_path, extension)))
    
    for logo_path in logos:
        logo = cv2.imread(logo_path, cv2.IMREAD_UNCHANGED)  # Read with alpha channel if present
        # Handle formats without an alpha channel
        if logo is not None and logo.shape[2] < 4:
            logo = cv2.cvtColor(logo, cv2.COLOR_BGR2BGRA)
        for i in range(num_images_per_logo):
            synthetic_image = apply_transformations_and_overlay_on_gray(logo, background_size)
            
            # Save the synthetic image
            logo_basename = os.path.basename(logo_path).split('.')[0]
            output_filename = f"{logo_basename}_{i}.jpg"
            cv2.imwrite(os.path.join(output_path, output_filename), synthetic_image)

# Specify your directories
logos_path = 'Output'
output_path = 'outputZ'

generate_synthetic_images_on_gray(logos_path, output_path)

# %% [markdown]
# annoteted

# %%
import cv2
import numpy as np
import os
from glob import glob
import csv

def create_gray_background(height, width, gray_level=220):
    """Creates a uniform gray background image."""
    return np.full((height, width, 3), gray_level, dtype=np.uint8)

def apply_transformations_and_overlay_on_gray(logo, background_size=(1024, 1024), scale_range=(0.05, 0.2)):
    # Generate a gray background
    background = create_gray_background(*background_size)
    
    # Scale the logo to a random size within the specified range
    scale = np.random.uniform(*scale_range)
    logo_height, logo_width = logo.shape[:2]
    new_width = int(logo_width * scale)
    new_height = int(logo_height * scale)
    resized_logo = cv2.resize(logo, (new_width, new_height), interpolation=cv2.INTER_AREA)
    
    # Choose a random position for the logo
    max_x = background_size[1] - new_width
    max_y = background_size[0] - new_height
    x = np.random.randint(0, max_x)
    y = np.random.randint(0, max_y)
    
    # Overlay the logo onto the gray background
    for c in range(0, 3):
        alpha_logo = resized_logo[:, :, 3] / 255.0
        alpha_bg = 1.0 - alpha_logo
        background[y:y+new_height, x:x+new_width, c] = (alpha_logo * resized_logo[:, :, c] +
                                                        alpha_bg * background[y:y+new_height, x:x+new_width, c])
    
    # Return the background and the bounding box as (x, y, x+w, y+h)
    return background, (x, y, x+new_width, y+new_height)

def generate_synthetic_images_on_gray(logos_path, output_path, annotation_file_path, num_images_per_logo=10, background_size=(1024, 1024)):
    logos = []
    image_extensions = ['*.png', '*.webp', '*.jpeg', '*.jpg']
    for extension in image_extensions:
        logos.extend(glob(os.path.join(logos_path, extension)))
    
    with open(annotation_file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["filename", "width", "height", "class", "xmin", "ymin", "xmax", "ymax"])  # Header
        
        for logo_path in logos:
            logo = cv2.imread(logo_path, cv2.IMREAD_UNCHANGED)
            if logo is not None and logo.shape[2] < 4:
                logo = cv2.cvtColor(logo, cv2.COLOR_BGR2BGRA)
            
            for i in range(num_images_per_logo):
                synthetic_image, bbox = apply_transformations_and_overlay_on_gray(logo, background_size)
                
                # Save the synthetic image
                logo_basename = os.path.basename(logo_path).split('.')[0]
                output_filename = f"{logo_basename}_{i}.jpg"
                cv2.imwrite(os.path.join(output_path, output_filename), synthetic_image)
                
                # Write the bounding box annotation to the CSV file
                writer.writerow([os.path.join(output_path, output_filename), background_size[1], background_size[0], logo_basename, *bbox])

# Specify your directories and annotation file path
# Specify your directories
logos_path = 'Output'
output_path = 'synthetic_annotated'
annotation_file_path = 'annotations.csv'

generate_synthetic_images_on_gray(logos_path, output_path, annotation_file_path)

# %% [markdown]
# well formatted csv

# %%
import cv2
import numpy as np
import os
from glob import glob
import csv

def create_gray_background(height, width, gray_level=220):
    """Creates a uniform gray background image."""
    return np.full((height, width, 3), gray_level, dtype=np.uint8)

def apply_transformations_and_overlay_on_gray(logo, background_size=(1024, 1024), scale_range=(0.05, 0.2)):
    # Generate a gray background
    background = create_gray_background(*background_size)
    
    # Scale the logo to a random size within the specified range
    scale = np.random.uniform(*scale_range)
    logo_height, logo_width = logo.shape[:2]
    new_width = int(logo_width * scale)
    new_height = int(logo_height * scale)
    resized_logo = cv2.resize(logo, (new_width, new_height), interpolation=cv2.INTER_AREA)
    
    # Choose a random position for the logo
    max_x = background_size[1] - new_width
    max_y = background_size[0] - new_height
    x = np.random.randint(0, max_x)
    y = np.random.randint(0, max_y)
    
    # Overlay the logo onto the gray background
    for c in range(0, 3):
        alpha_logo = resized_logo[:, :, 3] / 255.0
        alpha_bg = 1.0 - alpha_logo
        background[y:y+new_height, x:x+new_width, c] = (alpha_logo * resized_logo[:, :, c] +
                                                        alpha_bg * background[y:y+new_height, x:x+new_width, c])
    
    # Return the background and the bounding box as normalized (xmin, ymin, xmax, ymax)
    return background, (x / background_size[1], y / background_size[0], (x + new_width) / background_size[1], (y + new_height) / background_size[0])

def generate_synthetic_images_and_annotations(logos_path, output_path, annotation_file_path, num_images_per_logo=10, background_size=(1024, 1024), dataset_type='TRAINING'):
    logos = []
    image_extensions = ['*.png', '*.webp', '*.jpeg', '*.jpg']
    for extension in image_extensions:
        logos.extend(glob(os.path.join(logos_path, extension)))
    
    with open(annotation_file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        # Adjusted header to match the provided format
        writer.writerow(["SET", "IMAGE_PATH", "LABEL", "X_MIN","Y_MIN","X_MAX","Y_MIN", "X_MAX","Y_MAX","X_MIN","Y_MAX"])  # Header
        for logo_path in logos:
            logo = cv2.imread(logo_path, cv2.IMREAD_UNCHANGED)
            if logo is not None and logo.shape[2] < 4:
                logo = cv2.cvtColor(logo, cv2.COLOR_BGR2BGRA)
            
# ... (the rest of your script remains the same until the for loop)

            for i in range(num_images_per_logo):
                synthetic_image, bbox = apply_transformations_and_overlay_on_gray(logo, background_size)
                
                # Save the synthetic image
                logo_basename = os.path.basename(logo_path).split('.')[0]
                output_filename = f"{logo_basename}_{i}.jpg"
                image_path = os.path.join(output_path, output_filename).replace("\\", "/")  # Replace backslashes with forward slashes
                cv2.imwrite(image_path, synthetic_image)
                
                # Calculate the bounding box coordinates in the desired order
                xmin, ymin, xmax, ymax = bbox
                # A: Top-left
                Ax, Ay = xmin, ymin
                # B: Top-right
                Bx, By = xmax, ymin
                # C: Bottom-right
                Cx, Cy = xmax, ymax
                # D: Bottom-left
                Dx, Dy = xmin, ymax
                
                # Assuming all images are used for the same dataset type (training, test, validation)
                writer.writerow([dataset_type, f"gs://bucket_mounim/{image_path}", logo_basename, Ax, Ay, Bx, By, Cx, Cy, Dx, Dy])

# ... (the rest of your script)


# Specify your directories and annotation file path
logos_path = 'Output'
output_path = 'well_formatted'
annotation_file_path = 'well_format_annotations3.csv'

generate_synthetic_images_and_annotations(logos_path, output_path, annotation_file_path)

# %%
import cv2
import numpy as np
import os
from glob import glob
import csv

def create_gray_background(height, width, gray_level=220):
    """Creates a uniform gray background image."""
    return np.full((height, width, 3), gray_level, dtype=np.uint8)

def apply_transformations_and_overlay_on_gray(logo, background_size=(1024, 1024), scale_range=(0.05, 0.2)):
    """Generates a synthetic image with a transformed logo on a gray background."""
    background = create_gray_background(*background_size)
    scale = np.random.uniform(*scale_range)
    logo_height, logo_width = logo.shape[:2]
    new_width = int(logo_width * scale)
    new_height = int(logo_height * scale)
    resized_logo = cv2.resize(logo, (new_width, new_height), interpolation=cv2.INTER_AREA)

    max_x = background_size[1] - new_width
    max_y = background_size[0] - new_height
    x = np.random.randint(0, max_x)
    y = np.random.randint(0, max_y)

    for c in range(0, 3):
        alpha_logo = resized_logo[:, :, 3] / 255.0
        alpha_bg = 1.0 - alpha_logo
        background[y:y+new_height, x:x+new_width, c] = (alpha_logo * resized_logo[:, :, c] +
                                                        alpha_bg * background[y:y+new_height, x:x+new_width, c])

    # Normalize the bounding box coordinates to be relative to the image size
    xmin = x / background_size[1]
    ymin = y / background_size[0]
    xmax = (x + new_width) / background_size[1]
    ymax = (y + new_height) / background_size[0]

    return background, (xmin, ymin, xmax, ymin, xmax, ymax, xmin, ymax)

def generate_synthetic_images_and_annotations(logos_path, output_path, annotation_file_path, num_images_per_logo=10, background_size=(1024, 1024), dataset_type='TRAINING'):
    """Generates synthetic images with annotations."""
    logos = []
    image_extensions = ['*.png', '*.webp', '*.jpeg', '*.jpg']
    for extension in image_extensions:
        logos.extend(glob(os.path.join(logos_path, extension)))

    with open(annotation_file_path, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["ML_USE", "GCS_FILE_PATH", "LABEL", "X_MIN", "Y_MIN", "X_MAX", "Y_MIN", "X_MAX", "Y_MAX", "X_MIN", "Y_MAX"])  # Header

        for logo_path in logos:
            logo = cv2.imread(logo_path, cv2.IMREAD_UNCHANGED)
            if logo is not None and logo.shape[2] < 4:
                logo = cv2.cvtColor(logo, cv2.COLOR_BGR2BGRA)

            for i in range(num_images_per_logo):
                synthetic_image, bbox = apply_transformations_and_overlay_on_gray(logo, background_size)
                logo_basename = os.path.basename(logo_path).split('.')[0]
                output_filename = f"{logo_basename}_{i}.jpg"
                image_path = os.path.join(output_path, output_filename).replace("\\", "/")
                cv2.imwrite(image_path, synthetic_image)

                # Write the annotation with eight coordinates
                writer.writerow([dataset_type, f"gs://your-bucket-name/{image_path}", logo_basename, *bbox])

# Specify your directories and annotation file path
logos_path = 'Output'
output_path = 'well_formatted'
annotation_file_path = 'well_format_annotations4.csv'

generate_synthetic_images_and_annotations(logos_path, output_path, annotation_file_path)

# %%
from PIL import Image, ImageDraw

# Load the logo
logo_path = 'Output/1.png'  # Replace with the path to your logo
logo = Image.open(logo_path)

# Create a gray background image
background_size = (1400, 1900)  # Example size, adjust as needed
gray_color = (128, 128, 128)  # RGB representation of gray
background = Image.new('RGB', background_size, color=gray_color)

# Calculate the position to place the logo (e.g., center of the background)
logo_width, logo_height = logo.size
background_width, background_height = background_size
x = (background_width - logo_width) // 2
y = (background_height - logo_height) // 2

# Place the logo on the gray background
background.paste(logo, (x, y), logo)

# Calculate bounding box coordinates (top-left, top-right, bottom-right, bottom-left, and midpoints)
top_left = (x, y)
top_right = (x + logo_width, y)
bottom_right = (x + logo_width, y + logo_height)
bottom_left = (x, y + logo_height)
mid_top = ((x + x + logo_width) // 2, y)
mid_right = (x + logo_width, (y + y + logo_height) // 2)
mid_bottom = ((x + x + logo_width) // 2, y + logo_height)
mid_left = (x, (y + y + logo_height) // 2)

# Coordinates for bounding boxes
bounding_box_coords = [top_left, mid_top, top_right, mid_right, bottom_right, mid_bottom, bottom_left, mid_left]

# Optionally draw the bounding box for visualization (remove in production)
draw = ImageDraw.Draw(background)
draw.line(bounding_box_coords + [bounding_box_coords[0]], fill=(255, 0, 0), width=2)

# Save the composite image
background.save('composite_image_with_logo.png')

print("Bounding box coordinates:", bounding_box_coords)
# Out:
# Bounding box coordinates: [(636, 886), (700, 886), (764, 886), (764, 950), (764, 1014), (700, 1014), (636, 1014), (636, 950)]

# %%
import os
from PIL import Image
import random
import csv

# Configuration
logo_directory = 'Output'  # Replace with your logo directory path
background_size = (1200, 1600)
gray_color = (128, 128, 128)
number_of_images_per_logo = 10
usage_tags = ['TEST', 'TRAINING', 'VALIDATION']
output_directory = 'Input5'  # Directory to save images and CSV
min_scale = 0.1  # Minimum scale factor
max_scale = 0.5 # Maximum scale factor

# Ensure output directory exists
os.makedirs(output_directory, exist_ok=True)
# Function to get a valid random scale factor that ensures the logo fits the background
def get_valid_scale_factor(logo_size, min_scale, max_scale, background_size):
    # Calculate the maximum scale where the logo can fit to the background
    max_logo_scale_width = background_size[0] / logo_size[0]
    max_logo_scale_height = background_size[1] / logo_size[1]

    # Choose the smaller of the two scales to ensure the logo will fit in both dimensions
    max_possible_scale = min(max_logo_scale_width, max_logo_scale_height)

    # Ensure max_scale does not exceed the max possible scale
    valid_max_scale = min(max_scale, max_possible_scale)

    # Ensure min_scale is less than valid_max_scale
    valid_min_scale = min(min_scale, valid_max_scale)

    # Generate a random scale factor within the valid range
    return random.uniform(valid_min_scale, valid_max_scale)

def calculate_normalized_bounding_box(x, y, logo_width, logo_height, background_width, background_height):
    # Calculate normalized coordinates
    x_min = x / background_width
    y_min = y / background_height
    x_max = (x + logo_width) / background_width
    y_max = (y + logo_height) / background_height
    
    # Return the bounding box as eight numerical values
    return x_min, y_min, x_max, y_min, x_max, y_max, x_min, y_max
# Function to handle transparency when pasting logos
def paste_with_transparency(target_image, source_image, position):
    if source_image.mode in ('RGBA', 'LA') or (source_image.mode == 'P' and 'transparency' in source_image.info):
        # Use the alpha channel as mask
        target_image.paste(source_image, position, source_image)
    else:
        # No transparency to handle
        target_image.paste(source_image, position)
# Load all logos
logos = [os.path.join(logo_directory, f) for f in os.listdir(logo_directory) if os.path.isfile(os.path.join(logo_directory, f))]

# Initialize CSV data
csv_data = [["ML_USE", "GCS_FILE_PATH", "LABEL", "BOUNDING_BOX"]]
for logo_path in logos:
    label = 'L' + os.path.basename(logo_path).split(".")[0] if os.path.basename(logo_path)[0].isdigit() else os.path.basename(logo_path).split(".")[0]

    for i in range(number_of_images_per_logo):
        # Create a gray background
        background = Image.new('RGB', background_size, color=gray_color)
        
        # Load the logo and convert to RGBA
        logo = Image.open(logo_path).convert("RGBA")
        
        # Get a valid random scale factor
        scale_factor = get_valid_scale_factor(logo.size, min_scale, max_scale, background_size)
        # Apply scaling
        scaled_logo_width = int(logo.size[0] * scale_factor)
        scaled_logo_height = int(logo.size[1] * scale_factor)
        scaled_logo = logo.resize((scaled_logo_width, scaled_logo_height), Image.LANCZOS)
        
        # Randomly choose position
        x = random.randint(0, max(background_size[0] - scaled_logo_width, 0))
        y = random.randint(0, max(background_size[1] - scaled_logo_height, 0))
        
        # Place the logo with handling for transparency
        paste_with_transparency(background, scaled_logo, (x, y))
        
        # Calculate bounding box
        bounding_box = calculate_normalized_bounding_box(x, y, scaled_logo_width, scaled_logo_height, background_size[0], background_size[1])
        
        # Save the image
        image_name = f'{label}_{i}.png'
        image_path = os.path.join(output_directory, image_name)
        background.save(image_path, format='PNG')  # Save as PNG to preserve transparency
        
        # Prepare CSV line
        gcs_path = f'gs://bucket_mounim/Input3/{image_name}'  # Replace with your actual GCS path
        usage_tag = random.choice(usage_tags)
        csv_line = [usage_tag, gcs_path, label, bounding_box]
        csv_data.append(csv_line)

# Write the CSV data to a file
csv_filename = os.path.join(output_directory, 'logos_bounding_boxes.csv')
with open(csv_filename, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerows(csv_data)

# Output CSV file path
print(f'CSV file saved to: {csv_filename}')
# Out:
# CSV file saved to: Input4\logos_bounding_boxes.csv

# %%
import os
from PIL import Image
import random
import csv

# Configuration
logo_directory = 'Output'  # Replace with your logo directory path
background_size = (1200, 1600)
gray_color = (128, 128, 128)
number_of_images_per_logo = 10
usage_tags = ['TEST', 'TRAINING', 'VALIDATION']
output_directory = 'Input6'  # Directory to save images and CSV
min_scale = 0.1  # Minimum scale factor
max_scale = 0.5  # Maximum scale factor

# Ensure output directory exists
os.makedirs(output_directory, exist_ok=True)

# Function to get a valid random scale factor that ensures the logo fits the background
def get_valid_scale_factor(logo_size, min_scale, max_scale, background_size):
    max_logo_scale_width = background_size[0] / logo_size[0]
    max_logo_scale_height = background_size[1] / logo_size[1]
    max_possible_scale = min(max_logo_scale_width, max_logo_scale_height)
    valid_max_scale = min(max_scale, max_possible_scale)
    valid_min_scale = min(min_scale, valid_max_scale)
    return random.uniform(valid_min_scale, valid_max_scale)

# Function to calculate normalized bounding box
def calculate_normalized_bounding_box(x, y, logo_width, logo_height, background_width, background_height):
    x_min = x / background_width
    y_min = y / background_height
    x_max = (x + logo_width) / background_width
    y_max = (y + logo_height) / background_height
    return x_min, y_min, x_max, y_min, x_max, y_max, x_min, y_max

# Function to handle transparency when pasting logos
def paste_with_transparency(target_image, source_image, position):
    if source_image.mode in ('RGBA', 'LA') or (source_image.mode == 'P' and 'transparency' in source_image.info):
        target_image.paste(source_image, position, source_image)
    else:
        target_image.paste(source_image, position)

# Load all logos
logos = [os.path.join(logo_directory, f) for f in os.listdir(logo_directory) if os.path.isfile(os.path.join(logo_directory, f))]

# Initialize CSV data
csv_data = [["ML_USE", "GCS_FILE_PATH", "LABEL", "X_MIN", "Y_MIN", "X_MAX", "Y_MIN", "X_MAX", "Y_MAX", "X_MIN", "Y_MAX"]]

for logo_path in logos:
    # Extract label and prepend 'L' if it starts with a digit
    raw_label = os.path.basename(logo_path).split(".")[0]
    label = f"L{raw_label}" if raw_label[0].isdigit() else raw_label

    for i in range(number_of_images_per_logo):
        # Create a gray background
        background = Image.new('RGB', background_size, color=gray_color)
        
        # Load the logo and convert to RGBA
        logo = Image.open(logo_path).convert("RGBA")
        
        # Get a valid random scale factor
        scale_factor = get_valid_scale_factor(logo.size, min_scale, max_scale, background_size)
        # Apply scaling
        scaled_logo_width = int(logo.size[0] * scale_factor)
        scaled_logo_height = int(logo.size[1] * scale_factor)
        scaled_logo = logo.resize((scaled_logo_width, scaled_logo_height), Image.LANCZOS)
        
        # Randomly choose position
        x = random.randint(0, max(background_size[0] - scaled_logo_width, 0))
        y = random.randint(0, max(background_size[1] - scaled_logo_height, 0))
        
        # Place the logo with handling for transparency
        paste_with_transparency(background, scaled_logo, (x, y))
        
        # Calculate bounding box
        bbox_values = calculate_normalized_bounding_box(x, y, scaled_logo_width, scaled_logo_height, background_size[0], background_size[1])
        
        # Save the image
        image_name = f'{label}_{i}.png'
        image_path = os.path.join(output_directory, image_name)
        background.save(image_path, format='PNG')
        
        # Prepare CSV line
        gcs_path = f'gs://bucket_mounim/Input6/{image_name}'  # Replace with your actual GCS path
        usage_tag = random.choice(usage_tags)
        
        # Combine the usage tag, GCS path, label, and bounding box values
        csv_line = [usage_tag, gcs_path, label] + list(bbox_values)
        csv_data.append(csv_line)

# Write the CSV data to a file
csv_filename = os.path.join(output_directory, 'logos_bounding_boxes.csv')
with open(csv_filename, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerows(csv_data)

# Output CSV file path
print(f'CSV file saved to: {csv_filename}')
# Out:
# CSV file saved to: Input6\logos_bounding_boxes.csv

# %% [markdown]
# # Split

# %%
import os
from PIL import Image

def split_and_resize_images(input_folder, output_folder, num_splits, new_width, new_height):
    os.makedirs(output_folder, exist_ok=True)  # Create output folder if it doesn't exist
    
    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)
            split_height = image.height // num_splits
            
            for i in range(num_splits):
                # Calculate the bounding box for each split
                bbox = (0, i * split_height, image.width, (i + 1) * split_height if (i + 1) < num_splits else image.height)
                split_image = image.crop(bbox)
                # Resize the split image to new dimensions
                resized_image = split_image.resize((new_width, new_height), Image.LANCZOS)
                
                # Construct the new filename and save the resized image
                split_image_path = os.path.join(output_folder, f'split_{filename.split(".")[0]}_{i}.png')
                resized_image.save(split_image_path)

# Define your parameters
input_folder = 'annotation_dataset'
output_folder = 'annotation_dataset_REAL'
num_splits = 5
new_width = 1200
new_height = 1600

# Execute the function
split_and_resize_images(input_folder, output_folder, num_splits, new_width, new_height)
